# %% [markdown]
# <a href="https://colab.research.google.com/github/h-y-liu/MLRepository/blob/main/Sec_1_Homework_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0.) Import and Clean data

# %%
import pandas as pd
# from google.colab import drive
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
#drive.mount('/content/gdrive/', force_remount = True)
df = pd.read_csv("/content/Country-data.csv", sep = ",")

# %%
df.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
names = df[["country"]].copy()
X = df.drop(["country"], axis = 1)

# %%
scaler = StandardScaler().fit(X)
X_scaled = scaler.transform(X)

# %% [markdown]
# # 1.) Fit a kmeans Model with any Number of Clusters

# %%
kmeans = KMeans(n_clusters = 5).fit(X_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# # 2.) Pick two features to visualize across

# %%
X.columns
# Out:
# Index(['child_mort', 'exports', 'health', 'imports', 'income', 'inflation',
#        'life_expec', 'total_fer', 'gdpp'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

x1_index = 0
x2_index = 4


scatter = plt.scatter(X_scaled[:, x1_index], X_scaled[:, x2_index], c=kmeans.labels_, cmap='viridis', label='Clusters')


centers = plt.scatter(kmeans.cluster_centers_[:, x1_index], kmeans.cluster_centers_[:, x2_index], marker='o', color='black', s=100, label='Centers')

plt.xlabel(X.columns[x1_index])
plt.ylabel(X.columns[x2_index])
plt.title('Scatter Plot of Customers')

# Generate legend
plt.legend()

plt.grid()
plt.show()

# %% [markdown]
# # 3.) Check a range of k-clusters and visualize to find the elbow. Test 30 different random starting places for the centroid means

# %%
WCSSs  = []
ks = range(1,15)
for k in ks:
    kmeans = kmeans = KMeans(n_clusters = k, n_init = 30, init = "random")
    kmeans.fit(X_scaled)
    WCSSs.append(kmeans.inertia_)

# %%
# Bonus optional
# WCSSs = [KMeans(n_clusters = k, n_init = 30, init = "random").fit(X_scaled)inertia_ for k in range(1,15)]

# %%
WCSSs
# Out:
# [1503.0,
#  1050.2145582853307,
#  831.4244352086876,
#  700.3229986404376,
#  628.6566924513245,
#  564.0203792020267,
#  506.51528637952373,
#  454.0589590676119,
#  422.9602171720212,
#  398.20945339195293,
#  377.0647015991026,
#  352.9200101878057,
#  343.0570114257822,
#  321.5413411505503]

# %% [markdown]
# # 4.) Use the above work and economic critical thinking to choose a number of clusters. Explain why you chose the number of clusters and fit a model accordingly.

# %%
plt.plot(ks, WCSSs)
plt.xlabel("# of clusters")
plt.ylabel("WCSS")
plt.grid()

# %% [markdown]
# # 6.) Do the same for a silhoutte plot

# %%
from sklearn.metrics import silhouette_score

# %%
SCs = []
ks = range(2,15)
for k in ks:
    kmeans = kmeans = KMeans(n_clusters = k, n_init = 30, init = "random")
    kmeans.fit(X_scaled)
    labs = kmeans.labels_
    SCs.append(silhouette_score(X_scaled, labs))

# %%
plt.plot(SCs)
plt.xlabel("# of clusters")
plt.ylabel("SC")
plt.show()

# %% [markdown]
# # 7.) Create a list of the countries that are in each cluster. Write interesting things you notice.

# %%
kmeans = KMeans(n_clusters = 2, n_init = 30, init = "random").fit(X_scaled)

# %%
preds = pd.DataFrame(kmeans.predict(X_scaled))

# %%
output = pd.concat([preds, df], axis = 1)

# %%
output
# Out:
#      0              country  child_mort  exports  health  imports  income  \
# 0    1          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1    0              Albania        16.6     28.0    6.55     48.6    9930
# 2    0              Algeria        27.3     38.4    4.17     31.4   12900
# 3    1               Angola       119.0     62.3    2.85     42.9    5900
# 4    0  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..  ..                  ...         ...      ...     ...      ...     ...
# 162  1              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163  0            Venezuela        17.1     28.5    4.91     17.6   16500
# 164  0              Vietnam        23.3     72.0    6.84     80.2    4490
# 165  1                Yemen        56.3     30.0    5.18     34.4    4480
# 166  1               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# ...

# %%
print("Cluster 1: ")
list(output.loc[output[0] == 0, "country"])
# Out:
# Cluster 1:
# ['Albania',
#  'Algeria',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Bhutan',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Brunei',
#  'Bulgaria',
#  'Canada',
#  'Cape Verde',
#  'Chile',
#  'China',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'El Salvador',
#  'Estonia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Grenada',
#  'Hungary',
#  'Iceland',
#  'Iran',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kuwait',
#  'Latvia',
#  'Lebanon',
#  'Libya',
#  'Lithuania',
#  'Luxembourg',
#  'Macedonia, FYR',
#  'Malaysia',
#  'Maldives',
#  'Malta',
#  'Mauritius',
#  'Moldova',
#  'Montenegro',
#  'Morocco',
#  'Netherlands',
# ...

# %%
print("Cluster 2: ")
list(output.loc[output[0] == 1, "country"])
# Out:
# Cluster 2:
# ['Afghanistan',
#  'Angola',
#  'Bangladesh',
#  'Benin',
#  'Bolivia',
#  'Botswana',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Central African Republic',
#  'Chad',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  "Cote d'Ivoire",
#  'Egypt',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Gabon',
#  'Gambia',
#  'Ghana',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'India',
#  'Indonesia',
#  'Iraq',
#  'Kenya',
#  'Kiribati',
#  'Kyrgyz Republic',
#  'Lao',
#  'Lesotho',
#  'Liberia',
#  'Madagascar',
#  'Malawi',
#  'Mali',
#  'Mauritania',
#  'Micronesia, Fed. Sts.',
#  'Mongolia',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nepal',
#  'Niger',
#  'Nigeria',
#  'Pakistan',
#  'Philippines',
#  'Rwanda',
#  'Samoa',
#  'Senegal',
#  'Sierra Leone',
#  'Solomon Islands',
#  'South Africa',
#  'Sudan',
#  'Tajikistan',
#  'Tanzania',
#  'Timor-Leste',
#  'Togo',
#  'Tonga',
#  'Turkmenistan',
# ...

# %% [markdown]
# #### Write an observation :
# The first cluster contains countries generally recognized for higher income levels, lower child mortality rates, and better overall health outcomes, showcasing advanced economies with robust healthcare systems and higher life expectancies. These countries are from diverse geographical regions but share commonalities in economic prosperity and development. In contrast, the second cluster comprises countries primarily from lower-income brackets, with higher rates of child mortality, lower GDP per capita, and challenges in health care accessibility. This cluster includes many countries from Sub-Saharan Africa, Asia, and a few from Latin America, highlighting regions where development challenges are more acute. The stark differences between the two clusters underline the global inequality in wealth, health, and overall living conditions.

# %% [markdown]
# # 8.) Create a table of Descriptive Statistics. Rows being the Cluster number and columns being all the features. Values being the mean of the centroid. Use the nonscaled X values for interprotation

# %%
#kmeans....

# %%
output.groupby(0).mean()
# Out:
# <ipython-input-23-e9a27c4e94ce>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   output.groupby(0).mean()
#    child_mort    exports    health    imports        income  inflation  \
# 0
# 0   12.161616  48.603030  7.314040  49.121212  26017.171717   5.503545
# 1   76.280882  30.198515  6.090147  43.642146   4227.397059  11.098750
#
#    life_expec  total_fer          gdpp
# 0
# 0   76.493939   1.941111  20507.979798
# 1   61.910294   4.413824   1981.235294

# %%
output.groupby(0).std()
# Out:
# <ipython-input-24-96ffda24b430>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   output.groupby(0).std()
#    child_mort    exports    health    imports        income  inflation  \
# 0
# 0    8.523122  30.116032  2.716652  26.928785  20441.749847   6.957187
# 1   38.076068  18.201742  2.645319  19.323451   4890.581414  13.682630
#
#    life_expec  total_fer          gdpp
# 0
# 0    3.735757   0.486744  20578.727127
# 1    6.897418   1.285590   2528.509189

# %% [markdown]
# # 9.) Write an observation about the descriptive statistics.

# %% [markdown]
# Cluster 0, presumably representing more developed nations, shows low child mortality (mean = 12.16) and high income (mean = 26017.17), with a higher life expectancy (mean = 76.49) and lower total fertility rate (mean = 1.94). This cluster also shows substantial economic activity with higher exports, imports, and GDPP (mean = 20507.98) than Cluster 1.
#
# Cluster 0 has relatively lower variability in child mortality (std = 8.52) and life expectancy (std = 3.73) compared to Cluster 1, which has higher variability (child mortality std = 38.07, life expectancy std = 6.89), suggesting more heterogeneity in health outcomes among less developed countries.
